# %% [markdown]
# #### IMPORTS

# %%
import torch
import numpy as np

from dataloader import MyCustomDataset
from torch.utils.data import DataLoader

import torch.nn as nn
import torch.optim as optim

import os
from model_nn import  Model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
default_dir = os.getcwd()
def default_directory():
    os.chdir(f"{default_dir}")
    print(f"you are back to the default directory: {default_dir}")

# %%
default_directory()
os.getcwd()
# Out:
# you are back to the default directory: /home/karansingh/Documents/summer term/ECG_ML/MAIN
# '/home/karansingh/Documents/summer term/ECG_ML/MAIN'

# %%
os.chdir("ML/data_4")
os.getcwd()
# Out:
# '/home/karansingh/Documents/summer term/ECG_ML/MAIN/ML/data_4'

# %%
os.getcwd()
# Out:
# '/home/karansingh/Documents/summer term/ECG_ML/MAIN/ML/data_4'

# %% [markdown]
# #### LOAD DATA

# %%
## Create fake dataset for demonstration purposes

## Load your dataset and use 


data_ST_list = []
for i in range(10):
    cc = np.loadtxt('disease_ST_svd_'+str(i)+'.txt')
    data_ST_list.append(cc)
    print(f"data st of length {len(cc)} in {i} index loaded")


data_ST_list = np.array(data_ST_list)
images = np.resize(data_ST_list,(5000,10000))

labels=np.zeros(5000)

data_SB_list = []
for i in range(10):
    cc = np.loadtxt('disease_SB_svd_'+str(i)+'.txt')
    data_SB_list.append(cc)
    print(f"data sb of length {len(cc)} in {i} index loaded")
images = np.concatenate((images,np.resize(data_SB_list,(5000,10000))))
labels=np.concatenate((labels,np.ones(5000)))

data_SR_list = []
for i in range(10):
    cc = np.loadtxt('disease_SR_svd_'+str(i)+'.txt')
    data_SR_list.append(cc)
    print(f"data sr of length {len(cc)} in {i} index loaded")
images = np.concatenate((images,np.resize(data_SR_list,(5000,10000))))
labels=np.concatenate((labels,np.ones(5000)*2))
# Out:
# data st of length 500 in 0 index loaded
# data st of length 500 in 1 index loaded
# data st of length 500 in 2 index loaded
# data st of length 500 in 3 index loaded
# data st of length 500 in 4 index loaded
# data st of length 500 in 5 index loaded
# data st of length 500 in 6 index loaded
# data st of length 500 in 7 index loaded
# data st of length 500 in 8 index loaded
# data st of length 500 in 9 index loaded
# data sb of length 500 in 0 index loaded
# data sb of length 500 in 1 index loaded
# data sb of length 500 in 2 index loaded
# data sb of length 500 in 3 index loaded
# data sb of length 500 in 4 index loaded
# data sb of length 500 in 5 index loaded
# data sb of length 500 in 6 index loaded
# data sb of length 500 in 7 index loaded
# data sb of length 500 in 8 index loaded
# data sb of length 500 in 9 index loaded
# data sr of length 500 in 0 index loaded
# data sr of length 500 in 1 index loaded
# data sr of length 500 in 2 index loaded
# data sr of length 500 in 3 index loaded
# data sr of length 500 in 4 index loaded
# data sr of length 500 in 5 index loaded
# data sr of length 500 in 6 index loaded
# data sr of length 500 in 7 index loaded
# data sr of length 500 in 8 index loaded
# data sr of length 500 in 9 index loaded

# %%
default_directory()
print(len(images),len(labels))
from model_cnn import SmallCNN
print(images.shape)
images = images.reshape(15000,1,100,100)
images.shape
# Out:
# you are back to the default directory: /home/karansingh/Documents/summer term/ECG_ML/MAIN
# 15000 15000
# (15000, 10000)
# (15000, 1, 100, 100)

# %% [markdown]
# #### CREATE BATCHES

# %%
# Create an instance of your dataset

images_train, images_test, labels_train, labels_test = train_test_split(images, labels, test_size=0.2, random_state=42)
train_dataset = MyCustomDataset(images_train, labels_train)
test_dataset = MyCustomDataset(images_test, labels_test)
# Define a DataLoader
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# #### TRAINING PARAMETERS

# %%
torch.manual_seed(37)  # Set seed for reproducibility
model__ = SmallCNN()

criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
optimizer = optim.Adam(model__.parameters(), lr=0.001)  # Adam optimizer
def accuracy(y_true, y_pred):
    """Calculates accuracy between truth labels and predictions.

    Args:
        y_true (torch.Tensor): Truth labels for predictions.
        y_pred (torch.Tensor): Predictions to be compared to predictions.

    Returns:
        [torch.float]: Accuracy value between y_true and y_pred, e.g. 78.45
    """
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %% [markdown]
# #### TRAINING

# %%
test_losses_list=[]
torch.manual_seed(42)  # Set seed for reproducibility
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model__ = SmallCNN().to(device)

with torch.no_grad():
    model__.eval()
    test_loss, accuracy_test = 0.0, 0.0
    for i, (images, labels) in enumerate(test_dataloader):
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = model__(images)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        accuracy_test += accuracy(labels, outputs.argmax(dim=1))
test_losses_list.append(test_loss / len(test_dataloader))

print(accuracy_test / len(test_dataloader))
# Out:
# 32.33599290780142

# %%
# # torch.manual_seed(42)  # Set seed for reproducibility
# # device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# # model__ = SmallCNN().to(device)

# criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
# optimizer = torch.optim.SGD(model__.parameters(), lr=0.001) 
# # redyce lr
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.4)

# def accuracy(y_true, y_pred):
#     correct = torch.eq(y_true, y_pred).sum().item()
#     acc = (correct / len(y_pred)) * 100
#     return acc

# num_epochs = 40


# for epoch in range(num_epochs):
#     model__.train()
#     running_loss, accuracy_train = 0.0, 0.0
#     for i, (images, labels) in enumerate(train_dataloader):
#         images, labels = images.to(device), labels.to(device)  # Move data to GPU
#         outputs = model__(images)
#         loss = criterion(outputs, labels)
        
#         # Backward pass and optimization
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item()
#         accuracy_train += accuracy(labels, outputs.argmax(dim=1))
#     train_losses_list.append(running_loss / len(train_dataloader))
    
#     # Just calculating the test loss and accuracy
#     with torch.no_grad():
#         model__.eval()
#         test_loss, accuracy_test = 0.0, 0.0
#         for i, (images, labels) in enumerate(test_dataloader):
#             images, labels = images.to(device), labels.to(device)  # Move data to GPU
#             outputs = model__(images)
#             loss = criterion(outputs, labels)
#             test_loss += loss.item()
#             accuracy_test += accuracy(labels, outputs.argmax(dim=1))
#     test_losses_list.append(test_loss / len(test_dataloader))
    
#     accuracy_train_list.append(accuracy_train / len(train_dataloader))
#     accuracy_test_list.append(accuracy_test / len(test_dataloader))
#     scheduler.step()

#     print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {running_loss / len(train_dataloader):.4f}, Test Loss: {test_loss / len(test_dataloader):.4f}, Train Accuracy: {accuracy_train / len(train_dataloader):.4f}, Test Accuracy: {accuracy_test / len(test_dataloader):.4f}')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split

import copy

# -------------------------
# Define SmallCNN
# -------------------------
class SmallCNN(nn.Module):
    def __init__(self):
        super(SmallCNN, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        
        # Batch normalization
        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(128)
        
        # Pooling
        self.pool = nn.MaxPool2d(2, 2)
        
        # Dropout
        self.dropout_conv = nn.Dropout2d(0.2)
        self.dropout_fc = nn.Dropout(0.5)
        
        # Fully connected layers
        self.fc1 = nn.Linear(128*12*12, 512)
        self.fc2 = nn.Linear(512, 3)
    
    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.dropout_conv(x)
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.pool(F.relu(self.bn3(self.conv3(x))))
        x = x.view(-1, 128*12*12)
        x = F.relu(self.fc1(x))
        x = self.dropout_fc(x)
        x = self.fc2(x)
        return x

# %%
torch.manual_seed(42)  # Set seed for reproducibility
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model__ = SmallCNN().to(device)

criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
# optimizer = torch.optim.SGD(model__.parameters(), lr=0.001)  
optimizer = torch.optim.Adam(model__.parameters(), lr=0.5e-3, weight_decay=1e-4)

def compute_correct(y_true, y_pred):
    # Returns number of correct predictions (not %)
    return torch.eq(y_true, y_pred).sum().item()


num_epochs = 25
test_losses_list = []
train_losses_list = []
accuracy_train_list = []
accuracy_test_list = []

for epoch in range(num_epochs):
    model__.train()
    running_loss = 0.0
    total_correct_train = 0
    total_samples_train = 0

    for images, labels in train_dataloader:
        images, labels = images.to(device), labels.to(device)
        outputs = model__(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        total_correct_train += compute_correct(labels, outputs.argmax(dim=1))
        total_samples_train += labels.size(0)

    train_loss = running_loss / len(train_dataloader)
    accuracy_train = (total_correct_train / total_samples_train) * 100
    train_losses_list.append(train_loss)
    accuracy_train_list.append(accuracy_train)

    # Test
    model__.eval()
    test_loss = 0.0
    total_correct_test = 0
    total_samples_test = 0

    with torch.no_grad():
        for images, labels in test_dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model__(images)
            loss = criterion(outputs, labels)

            test_loss += loss.item()
            total_correct_test += compute_correct(labels, outputs.argmax(dim=1))
            total_samples_test += labels.size(0)

    test_loss = test_loss / len(test_dataloader)
    accuracy_test = (total_correct_test / total_samples_test) * 100
    test_losses_list.append(test_loss)
    accuracy_test_list.append(accuracy_test)

    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, '
          f'Train Accuracy: {accuracy_train:.2f}, Test Accuracy: {accuracy_test:.2f}')
# Out:
# Epoch [1/25], Train Loss: 0.4721, Test Loss: 0.1798, Train Accuracy: 83.92, Test Accuracy: 93.67
# Epoch [2/25], Train Loss: 0.1997, Test Loss: 0.1180, Train Accuracy: 93.27, Test Accuracy: 95.80
# Epoch [3/25], Train Loss: 0.1640, Test Loss: 0.1152, Train Accuracy: 94.62, Test Accuracy: 96.00
# Epoch [4/25], Train Loss: 0.1492, Test Loss: 0.1092, Train Accuracy: 94.79, Test Accuracy: 95.80
# Epoch [5/25], Train Loss: 0.1360, Test Loss: 0.1036, Train Accuracy: 95.58, Test Accuracy: 96.10
# Epoch [6/25], Train Loss: 0.1170, Test Loss: 0.1442, Train Accuracy: 96.15, Test Accuracy: 95.33
# Epoch [7/25], Train Loss: 0.1116, Test Loss: 0.1339, Train Accuracy: 96.12, Test Accuracy: 95.00
# Epoch [8/25], Train Loss: 0.1050, Test Loss: 0.1021, Train Accuracy: 96.36, Test Accuracy: 96.40
# Epoch [9/25], Train Loss: 0.0920, Test Loss: 0.1221, Train Accuracy: 97.02, Test Accuracy: 95.43
# Epoch [10/25], Train Loss: 0.0833, Test Loss: 0.1044, Train Accuracy: 97.32, Test Accuracy: 96.63
# Epoch [11/25], Train Loss: 0.0755, Test Loss: 0.0938, Train Accuracy: 97.29, Test Accuracy: 96.70
# Epoch [12/25], Train Loss: 0.0715, Test Loss: 0.1176, Train Accuracy: 97.55, Test Accuracy: 96.20
# Epoch [13/25], Train Loss: 0.0615, Test Loss: 0.1113, Train Accuracy: 97.92, Test Accuracy: 96.70
# Epoch [14/25], Train Loss: 0.0568, Test Loss: 0.1232, Train Accuracy: 97.88, Test Accuracy: 96.00
# Epoch [15/25], Train Loss: 0.0499, Test Loss: 0.1091, Train Accuracy: 98.21, Test Accuracy: 96.73
# Epoch [16/25], Train Loss: 0.0501, Test Loss: 0.1064, Train Accuracy: 98.09, Test Accuracy: 96.73
# Epoch [17/25], Train Loss: 0.0475, Test Loss: 0.1323, Train Accuracy: 98.22, Test Accuracy: 96.40
# Epoch [18/25], Train Loss: 0.0407, Test Loss: 0.1352, Train Accuracy: 98.52, Test Accuracy: 96.80
# Epoch [19/25], Train Loss: 0.0369, Test Loss: 0.1574, Train Accuracy: 98.74, Test Accuracy: 96.10
# Epoch [20/25], Train Loss: 0.0349, Test Loss: 0.2410, Train Accuracy: 98.79, Test Accuracy: 95.00
# Epoch [21/25], Train Loss: 0.0335, Test Loss: 0.1217, Train Accuracy: 98.79, Test Accuracy: 96.40
# Epoch [22/25], Train Loss: 0.0276, Test Loss: 0.1376, Train Accuracy: 98.98, Test Accuracy: 96.17
# Epoch [23/25], Train Loss: 0.0356, Test Loss: 0.1533, Train Accuracy: 98.71, Test Accuracy: 96.13
# Epoch [24/25], Train Loss: 0.0252, Test Loss: 0.1585, Train Accuracy: 99.03, Test Accuracy: 95.77
# Epoch [25/25], Train Loss: 0.0262, Test Loss: 0.1644, Train Accuracy: 99.02, Test Accuracy: 96.60

# %%
import copy
import torch
import torch.nn as nn

torch.manual_seed(42)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = SmallCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-4)

# Scheduler (reduce LR when test loss plateaus)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="min", factor=0.2, patience=3
)

def correct(pred, true): 
    return (pred == true).sum().item()

num_epochs, patience = 25, 6
train_losses, test_losses, acc_train, acc_test = [], [], [], []
best_acc, wait, best_model = 0, 0, None

for epoch in range(num_epochs):
    # --- Train ---
    model.train(); run_loss = 0; c_train = t_train = 0
    for x, y in train_dataloader:
        x, y = x.to(device), y.to(device)
        out = model(x); loss = criterion(out, y)
        optimizer.zero_grad(); loss.backward(); optimizer.step()
        run_loss += loss.item()
        c_train += correct(out.argmax(1), y); t_train += y.size(0)
    train_losses.append(run_loss/len(train_dataloader))
    acc_train.append(100*c_train/t_train)

    # --- Test ---
    model.eval(); run_loss = 0; c_test = t_test = 0
    with torch.no_grad():
        for x, y in test_dataloader:
            x, y = x.to(device), y.to(device)
            out = model(x); loss = criterion(out, y)
            run_loss += loss.item()
            c_test += correct(out.argmax(1), y); t_test += y.size(0)
    test_losses.append(run_loss/len(test_dataloader))
    acc_test.append(100*c_test/t_test)

    # --- LR scheduler step ---
    scheduler.step(test_losses[-1])
    # Print LR (optional)
    lr_now = optimizer.param_groups[0]['lr']

    # --- Early stopping ---
    if acc_test[-1] > best_acc:
        best_acc, wait = acc_test[-1], 0
        best_model = copy.deepcopy(model.state_dict())
    else:
        wait += 1
        if wait >= patience:
            print(f"⏹️ Early stopping at epoch {epoch+1}")
            break

    print(f"Epoch [{epoch+1}/{num_epochs}] | "
          f"Train Loss: {train_losses[-1]:.4f}, Test Loss: {test_losses[-1]:.4f}, "
          f"Train Acc: {acc_train[-1]:.2f}, Test Acc: {acc_test[-1]:.2f}, "
          f"LR: {lr_now:.6f}")

# Restore best weights
model.load_state_dict(best_model)
print(f"✅ Best Test Accuracy: {best_acc:.2f}")
# Out:
# Epoch [1/25] | Train Loss: 0.4742, Test Loss: 0.1729, Train Acc: 84.08, Test Acc: 94.27, LR: 0.000500
# Epoch [2/25] | Train Loss: 0.1987, Test Loss: 0.1312, Train Acc: 93.28, Test Acc: 95.00, LR: 0.000500
# Epoch [3/25] | Train Loss: 0.1610, Test Loss: 0.1145, Train Acc: 94.63, Test Acc: 96.00, LR: 0.000500
# Epoch [4/25] | Train Loss: 0.1526, Test Loss: 0.1038, Train Acc: 94.90, Test Acc: 96.23, LR: 0.000500
# Epoch [5/25] | Train Loss: 0.1386, Test Loss: 0.1020, Train Acc: 95.44, Test Acc: 96.20, LR: 0.000500
# Epoch [6/25] | Train Loss: 0.1199, Test Loss: 0.1593, Train Acc: 95.95, Test Acc: 94.57, LR: 0.000500
# Epoch [7/25] | Train Loss: 0.1135, Test Loss: 0.1365, Train Acc: 96.08, Test Acc: 94.73, LR: 0.000500
# Epoch [8/25] | Train Loss: 0.1027, Test Loss: 0.1049, Train Acc: 96.51, Test Acc: 96.43, LR: 0.000500
# Epoch [9/25] | Train Loss: 0.0960, Test Loss: 0.1113, Train Acc: 96.76, Test Acc: 96.17, LR: 0.000100
# Epoch [10/25] | Train Loss: 0.0635, Test Loss: 0.0917, Train Acc: 97.92, Test Acc: 96.93, LR: 0.000100
# Epoch [11/25] | Train Loss: 0.0535, Test Loss: 0.0939, Train Acc: 98.14, Test Acc: 96.87, LR: 0.000100
# Epoch [12/25] | Train Loss: 0.0484, Test Loss: 0.1003, Train Acc: 98.19, Test Acc: 96.70, LR: 0.000100
# Epoch [13/25] | Train Loss: 0.0424, Test Loss: 0.1049, Train Acc: 98.58, Test Acc: 96.83, LR: 0.000100
# Epoch [14/25] | Train Loss: 0.0383, Test Loss: 0.1026, Train Acc: 98.62, Test Acc: 96.80, LR: 0.000020
# ⏹️ Early stopping at epoch 15
# ✅ Best Test Accuracy: 96.93

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split

import copy

# -------------------------
# Define SmallCNN
# -------------------------
class SmallCNN(nn.Module):
    def __init__(self):
        super(SmallCNN, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        
        # Batch normalization
        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(128)
        
        # Pooling
        self.pool = nn.MaxPool2d(2, 2)
        
        # Dropout
        self.dropout_conv = nn.Dropout2d(0.1)
        self.dropout_fc = nn.Dropout(0.5)
        
        # Fully connected layers
        self.fc1 = nn.Linear(128*12*12, 512)
        self.fc2 = nn.Linear(512, 3)
    
    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.dropout_conv(x)
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.pool(F.relu(self.bn3(self.conv3(x))))
        x = x.view(-1, 128*12*12)
        x = F.relu(self.fc1(x))
        x = self.dropout_fc(x)
        x = self.fc2(x)
        return x

# %%
# save the model
default_directory()
torch.save(model__.state_dict(), 'model_smallCNN_new.pth')
# Out:
# you are back to the default directory: /home/karansingh/Documents/summer term/ECG_ML/MAIN

# %%
torch.manual_seed(42)  # Set seed for reproducibility
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model__ = SmallCNN().to(device)

criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
# optimizer = torch.optim.SGD(model__.parameters(), lr=0.001)  # Adam optimizer
optimizer = torch.optim.Adam(model__.parameters(), lr=1e-3, weight_decay=1e-4)

def accuracy(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

num_epochs = 25
test_losses_list = []
train_losses_list = []
accuracy_train_list = []
accuracy_test_list = []

for epoch in range(num_epochs):
    model__.train()
    running_loss, accuracy_train = 0.0, 0.0
    for i, (images, labels) in enumerate(train_dataloader):
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = model__(images)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        accuracy_train += accuracy(labels, outputs.argmax(dim=1))
    train_losses_list.append(running_loss / len(train_dataloader))
    
    # Just calculating the test loss and accuracy
    with torch.no_grad():
        model__.eval()
        test_loss, accuracy_test = 0.0, 0.0
        for i, (images, labels) in enumerate(test_dataloader):
            images, labels = images.to(device), labels.to(device)  # Move data to GPU
            outputs = model__(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            accuracy_test += accuracy(labels, outputs.argmax(dim=1))
    test_losses_list.append(test_loss / len(test_dataloader))
    
    accuracy_train_list.append(accuracy_train / len(train_dataloader))
    accuracy_test_list.append(accuracy_test / len(test_dataloader))

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {running_loss / len(train_dataloader):.4f}, Test Loss: {test_loss / len(test_dataloader):.4f}, Train Accuracy: {accuracy_train / len(train_dataloader):.4f}, Test Accuracy: {accuracy_test / len(test_dataloader):.4f}')
# Out:
# Epoch [1/25], Train Loss: 0.5972, Test Loss: 0.1522, Train Accuracy: 84.2500, Test Accuracy: 94.5035
# Epoch [2/25], Train Loss: 0.1929, Test Loss: 0.1201, Train Accuracy: 93.5667, Test Accuracy: 95.8444
# Epoch [3/25], Train Loss: 0.1591, Test Loss: 0.1127, Train Accuracy: 94.6000, Test Accuracy: 95.9774
# Epoch [4/25], Train Loss: 0.1475, Test Loss: 0.1107, Train Accuracy: 95.0917, Test Accuracy: 96.2101
# Epoch [5/25], Train Loss: 0.1311, Test Loss: 0.1023, Train Accuracy: 95.7750, Test Accuracy: 96.5426
# Epoch [6/25], Train Loss: 0.1189, Test Loss: 0.2010, Train Accuracy: 96.2000, Test Accuracy: 92.4978
# Epoch [7/25], Train Loss: 0.1123, Test Loss: 0.1188, Train Accuracy: 96.3250, Test Accuracy: 95.5452
# Epoch [8/25], Train Loss: 0.1027, Test Loss: 0.1030, Train Accuracy: 96.6333, Test Accuracy: 96.7753
# Epoch [9/25], Train Loss: 0.0990, Test Loss: 0.1229, Train Accuracy: 96.6917, Test Accuracy: 95.7336
# Epoch [10/25], Train Loss: 0.0830, Test Loss: 0.1273, Train Accuracy: 97.2333, Test Accuracy: 95.6006
# Epoch [11/25], Train Loss: 0.0750, Test Loss: 0.1747, Train Accuracy: 97.4000, Test Accuracy: 94.1600
# Epoch [12/25], Train Loss: 0.0723, Test Loss: 0.1210, Train Accuracy: 97.5833, Test Accuracy: 96.5426
# Epoch [13/25], Train Loss: 0.0660, Test Loss: 0.1480, Train Accuracy: 97.7750, Test Accuracy: 95.6782
# Epoch [14/25], Train Loss: 0.0629, Test Loss: 0.1146, Train Accuracy: 97.5917, Test Accuracy: 96.0439
# Epoch [15/25], Train Loss: 0.0536, Test Loss: 0.0977, Train Accuracy: 98.1417, Test Accuracy: 96.7420
# Epoch [16/25], Train Loss: 0.0559, Test Loss: 0.1044, Train Accuracy: 97.9833, Test Accuracy: 96.8085
# Epoch [17/25], Train Loss: 0.0480, Test Loss: 0.1325, Train Accuracy: 98.3167, Test Accuracy: 96.0439
# Epoch [18/25], Train Loss: 0.0392, Test Loss: 0.1633, Train Accuracy: 98.6500, Test Accuracy: 96.3098
# Epoch [19/25], Train Loss: 0.0408, Test Loss: 0.1350, Train Accuracy: 98.5500, Test Accuracy: 96.7753
# Epoch [20/25], Train Loss: 0.0392, Test Loss: 0.1028, Train Accuracy: 98.5583, Test Accuracy: 96.8085
# Epoch [21/25], Train Loss: 0.0384, Test Loss: 0.1112, Train Accuracy: 98.6167, Test Accuracy: 96.8418
# Epoch [22/25], Train Loss: 0.0342, Test Loss: 0.1240, Train Accuracy: 98.7417, Test Accuracy: 96.4650
# Epoch [23/25], Train Loss: 0.0325, Test Loss: 0.1191, Train Accuracy: 98.9250, Test Accuracy: 96.7420
# Epoch [24/25], Train Loss: 0.0293, Test Loss: 0.1446, Train Accuracy: 98.9917, Test Accuracy: 95.6671
# Epoch [25/25], Train Loss: 0.0370, Test Loss: 0.1927, Train Accuracy: 98.6167, Test Accuracy: 94.8692

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd

model__.eval()
y_pred = []
y_true = []
with torch.no_grad():
    for images, labels in test_dataloader:
        outputs = model__(images.to(device))
        _, predicted = torch.max(outputs, 1)
        y_pred.extend(predicted.cpu().numpy())
        y_true.extend(labels.cpu().numpy())

cm = confusion_matrix(y_true, y_pred)
cm = cm / cm.sum(axis=1)[:, np.newaxis]  # Normalize confusion matrix
df_cm = pd.DataFrame(cm, index=["ST", "SB", "SR"], columns=["ST", "SB", "SR"])
plt.figure(figsize=(10, 7))
sns.heatmap(df_cm, annot=True, cmap='Blues')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.title('Confusion Matrix')
plt.show()

# %%
#Classification Report for Test Data:

from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=["ST", "SB", "SR"]))
# Out:
#               precision    recall  f1-score   support
#
#           ST       0.97      0.97      0.97      1037
#           SB       0.97      0.98      0.97       970
#           SR       0.96      0.95      0.95       993
#
#     accuracy                           0.97      3000
#    macro avg       0.97      0.97      0.97      3000
# weighted avg       0.97      0.97      0.97      3000

# %%
# presicion recall curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import matplotlib.pyplot as plt

# Compute Precision-Recall and plot curve
precision = dict()
recall = dict()
average_precision = dict()
for i in range(3):
    precision[i], recall[i], _ = precision_recall_curve((np.array(y_true) == i).astype(int),
                                                        (np.array(y_pred) == i).astype(int))
    average_precision[i] = average_precision_score((np.array(y_true) == i).astype(int), (np.array(y_pred) == i).astype(int))

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(np.eye(3)[y_true].ravel(),
    np.eye(3)[y_pred].ravel())
average_precision["micro"] = average_precision_score(np.eye(3)[y_true], np.eye(3)[y_pred],
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
        .format(average_precision["micro"]))
plt.figure()
plt.step(recall['micro'], precision['micro'], where='post')


plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title(
    'Average precision score, micro-averaged over all classes: AP={0:0.2f}'
    .format(average_precision["micro"]))
plt.show()
# Out:
# Average precision score, micro-averaged over all classes: 0.94

# %%
# ROC curve
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

y_test = label_binarize(y_true, classes=[0, 1, 2])
y_score = label_binarize(y_pred, classes=[0, 1, 2])


n_classes = 3

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
            label='macro-average ROC curve (area = {0:0.2f})'
                ''.format(roc_auc["macro"]),
            color='navy', linestyle=':', linewidth=4)

colors = ['aqua', 'darkorange', 'cornflowerblue']

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %%
from plots import accuracy_and_validation_plots


# Example data: Replace these with your actual training and validation data
epochs_= list(range(1, len(train_losses_list)+1))

accuracy_and_validation_plots(epochs_, train_losses_list, test_losses_list, accuracy_train_list,accuracy_test_list).plot_figure("accuracy.png")

# %%
def model_train(train_dataloader, test_dataloader,n):
    torch.manual_seed(n)  # Set seed for reproducibility
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model__ = Model().to(device)

    criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for classification
    optimizer = optim.Adam(model__.parameters(), lr=0.001)  # Adam optimizer

    def accuracy(y_true, y_pred):
        correct = torch.eq(y_true, y_pred).sum().item()
        acc = (correct / len(y_pred)) * 100
        return acc

    num_epochs = 25
    test_losses_list = []
    train_losses_list = []
    accuracy_train_list = []
    accuracy_test_list = []

    for epoch in range(num_epochs):
        model__.train()
        running_loss, accuracy_train = 0.0, 0.0
        for i, (images, labels) in enumerate(train_dataloader):
            images, labels = images.to(device), labels.to(device)  # Move data to GPU
            outputs = model__(images)
            loss = criterion(outputs, labels)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            accuracy_train += accuracy(labels, outputs.argmax(dim=1))
        train_losses_list.append(running_loss / len(train_dataloader))
        
        # Just calculating the test loss and accuracy
        with torch.no_grad():
            model__.eval()
            test_loss, accuracy_test = 0.0, 0.0
            for i, (images, labels) in enumerate(test_dataloader):
                images, labels = images.to(device), labels.to(device)  # Move data to GPU
                outputs = model__(images)
                loss = criterion(outputs, labels)
                test_loss += loss.item()
                accuracy_test += accuracy(labels, outputs.argmax(dim=1))
        test_losses_list.append(test_loss / len(test_dataloader))
        
        accuracy_train_list.append(accuracy_train / len(train_dataloader))
        accuracy_test_list.append(accuracy_test / len(test_dataloader))

        #print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {running_loss / len(train_dataloader):.4f}, Test Loss: {test_loss / len(test_dataloader):.4f}, Train Accuracy: {accuracy_train / len(train_dataloader):.4f}, Test Accuracy: {accuracy_test / len(test_dataloader):.4f}')
    return train_losses_list, test_losses_list, accuracy_train_list, accuracy_test_list

# %%
from model_cnn import SmallCNN
